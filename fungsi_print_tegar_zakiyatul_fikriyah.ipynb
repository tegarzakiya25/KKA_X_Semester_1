# %% [markdown]
# <a href="https://colab.research.google.com/github/tegarzakiya25/KKA_X_Semester_1/blob/main/fungsi_print_tegar_zakiyatul_fikriyah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Tegar zakiyatul fikriyah
#
# Kelas:x.11
#
# No absen:35

# %% [markdown]
# Menampilkan teks bebas

# %%
print("Tegar zakiyatul fikriyah")
# Out:
# Tegar zakiyatul fikriyah

# %%
print("jenis blackpink")
# Out:
# jenis blackpink

# %% [markdown]
# Menampilkan nilai variabel

# %%
nama_saudara="lulu chanifa"
print(nama_saudara)
# Out:
# lulu chanifa

# %%
jumlah_saudara=3
print(jumlah_saudara)
# Out:
# 3

# %%
nama_idola = "rafi ahmad"
print (nama_idola)
print ("nama_idola")
# Out:
# rafi ahmad
# nama_idola

# %% [markdown]
# Menampilkan Teks bebas dan nilai Variabel

# %% [markdown]
# Menampilkan teks bebas dan Nilai Variabel Menggunakan tanda koma

# %%
print("saya memiliki saudara sebanyak)
# Out:
# saya memiliki saudara sebanyak lulu chanifa

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel Menggunakan Tanda Plus

# %%
print("Saya memiliki saudara sebanyak " + str(jumlah_saudara) + "." + "Nama saudara saya adalah " + nama_saudara + ".")
# Out:
# Saya memiliki saudara sebanyak 3.Nama saudara saya adalah lulu chanifa.

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel Menggunakan f String

# %%
print(f"Saya memiliki saudara sebanyak {jumlah_saudara}. Nama saudara saya adalah {nama_saudara}.")
# Out:
# Saya memiliki saudara sebanyak 3. Nama saudara saya adalah lulu chanifa.

# %% [markdown]
# #Escape Character

# %%
print("Nama: Tegar zakiyatul fikriyah")
print("Kelas: X.11")
print("No.Absen: 35")
# Out:
# Nama: Tegar zakiyatul fikriyah
# Kelas: X.11
# No.Absen: 35

# %%
print("Nama: Tegar  zakiyatul  fikriyah \nKelas: X.11\nNo.Absen: 35")
# Out:
# Nama: Tegar  zakiyatul  fikriyah
# Kelas: X.11
# No.Absen: 35

# %%
print("""Nama\t\t: Tegar Zakiyatul  Fikriyah
Kelas\t\t: X.11
No. Absen\t: 35""")
# Out:
# Nama		: Tegar Zakiyatul  Fikriyah
# Kelas		: X.11
# No. Absen	: 35

# %%
print("Tegar zakiyatul fikriyah")
# Out:
# Tegar zakiyatul fikriyah

# %%
print('Tegar Zakiyatul fikriyah')
# Out:
# Tegar Zakiyatul fikriyah

# %%
print('Habib ja\'far')
# Out:
# Habib ja'far

# %%
print("Habib ja'far")
# Out:
# Habib ja'far

# %%
print('Bu Shinta berkata,"Harap fokus menyimak!".')
# Out:
# Bu Shinta berkata,"Harap fokus menyimak!".

# %%
print("Bu Shinta berkata, \"Harap fokus menyimak!\".")
# Out:
# Bu Shinta berkata, "Harap fokus menyimak!".

# %%
print("Lokasi penyimpanan tugas KKA di D:\\MAN Demak\\KKA\\Tugas")
# Out:
# Lokasi penyimpanan tugas KKA di D:\MAN Demak\KKA\Tugas

# %% [markdown]
# #Fungsi Parameter

# %%
nama_siswa_1= "Daffanes"
nama_siswa_2= "Adzka"
nama_siswa_3= "Haidar"

print(nama_siswa_1, nama_siswa_2, sep="-")
# Out:
# Daffanes-Adzka

# %%
nama_siswa_1 = "Daffanes"
nama_siswa_2 = "Adzka"
nama_siswa_3 = "Haidar"

print(nama_siswa_3, nama_siswa_2, nama_siswa_1, nama_siswa_2, sep="*")
# Out:
# Haidar*Adzka*Daffanes*Adzka

# %%
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# Daffanes
# Adzka

# %%
print(nama_siswa_1, nama_siswa_2)
# Out:
# Daffanes Adzka

# %%
print(nama_siswa_1, end="-")
print(nama_siswa_2)
# Out:
# Daffanes-Adzka

# %% [markdown]
# #Latihan soal:
# Gunakan parameter end untuk menampilkan tulisan sebagai berikut:
# Haidar#Adzka#Daffanes#Adzka

# %%
print(nama_siswa_3, end="-")
print(nama_siswa_2, end="-")
print(nama_siswa_1, end="-")
print(nama_siswa_2, )
# Out:
# Haidar-Adzka-Daffanes-Adzka
