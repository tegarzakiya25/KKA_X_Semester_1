# %% [markdown]
# <a href="https://colab.research.google.com/github/tegarzakiya25/KKA_X_Semester_1/blob/main/fungsi_print_tegar_zakiyatul_fikriyah.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Tegar zakiyatul fikriyah
#
# Kelas:x.11
#
# No absen:35

# %% [markdown]
# Menampilkan teks bebas

# %%
print("Tegar zakiyatul fikriyah")
# Out:
# Tegar zakiyatul fikriyah

# %%
print("jenis blackpink")
# Out:
# jenis blackpink

# %% [markdown]
# Menampilkan nilai variabel

# %%
nama_saudara="lulu chanifa"
print(nama_saudara)
# Out:
# lulu chanifa

# %%
jumlah_saudara=3
print(jumlah_saudara)
# Out:
# 3

# %%
nama_idola = "rafi ahmad"
print (nama_idola)
print ("nama_idola")
# Out:
# rafi ahmad
# nama_idola

# %% [markdown]
# Menampilkan Teks bebas dan nilai Variabel

# %% [markdown]
# Menampilkan teks bebas dan Nilai Variabel Menggunakan tanda koma

# %%
print("saya memiliki saudara sebanyak", nama_saudara)
# Out:
# saya memiliki saudara sebanyak lulu chanifa

# %% [markdown]
# Menampilkan teks bebas dan nilai variabel menggunakan tanda plus

# %% [markdown]
# Menampilkan teks bebas dan nilai variabel menggunakan fstring

# %% [markdown]
# escape carakter

# %%
print("Nama:Tegar zakiyatul fikriyah")
print("Kelas: x.11")
print("No.Absen:35")
# Out:
# Nama:Tegar zakiyatul fikriyah
# Kelas: x.11
# No.Absen:35

# %%
print(f"saya memiliki saudara sebanyak{jumlah_saudara}.Nama saudara saya adalah{nama_saudara}.")
# Out:
# saya memiliki saudara sebanyak3.Nama saudara saya adalahlulu chanifa.

# %%
print("Nama:Tegar zakiyatul fikriyah\nkelas:x 11\nNo. Absen:35")
# Out:
# Nama:Tegar zakiyatul fikriyah
# kelas:x 11
# No. Absen:35

# %%
print('Tegar zakiyatul fikriyah')
# Out:
# Tegar zakiyatul fikriyah

# %%
print('rafi ahmad')
# Out:
# rafi ahmad

# %%
print('rafi halilintar')
# Out:
# rafi halilintar

# %%
print('Bu shinta berkata, "Harap fokus menyimak! ".')
# Out:
# Bu shinta berkata, "Harap fokus menyimak! ".

# %%
print("lokasi penyimpanan tugas kka di D:\MAN Demak\\MAN Demak \\ KKA\\Tugas ")
# Out:
# lokasi penyimpanan tugas kka di D:\MAN Demak\MAN Demak \ KKA\Tugas
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# /tmp/ipython-input-800986232.py:1: SyntaxWarning: invalid escape sequence '\M'
#   print("lokasi penyimpanan tugas kka di D:\MAN Demak\\MAN Demak \\ KKA\\Tugas ")

# %% [markdown]
# Fungsi parameter

# %%
nama_siswa_1="Daffanes"
nama_siswa_2="Adzka"
nama_siswa_3="Haidar"

print(nama_siswa_3,nama_siswa_2,nama_siswa_1,nama_siswa_2,sep="_")
# Out:
# Haidar_Adzka_Daffanes_Adzka

# %%
nama_siswa_1="Daffanes"
nama_siswa_2="Adzka"
nama_siswa_3="Haidar"

print(nama_siswa_1,nama_siswa_2, sep="_")
# Out:
# Daffanes_Adzka

# %%
print(nama_siswa_1)
print(nama_siswa_2)
# Out:
# Daffanes
# Adzka

# %%
print(nama_siswa_1,nama_siswa_2)
# Out:
# Daffanes Adzka

# %%
print(nama_siswa_1, end="_")
print(nama_siswa_2)
# Out:
# Daffanes_Adzka

# %% [markdown]
# Latihan soal

# %% [markdown]
# Gunakan parameter end untuk menampilkan tulisan sebagai berikut:

# %% [markdown]
# Haidar#Adzka#Daffanes#Adzka
