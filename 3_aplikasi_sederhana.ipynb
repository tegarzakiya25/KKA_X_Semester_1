# %% [markdown]
# <a href="https://colab.research.google.com/github/tegarzakiya25/KKA_X_Semester_1/blob/main/3_aplikasi_sederhana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama : Tegar zakiyatul fikriyah
#
# Kelas : x.11
#
# No.Absen : 35
#
# Nama Kelompok: Kucing Ngambek

# %% [markdown]
# Aplikasi Sederhana Menghitung Volume Bola

# %%
jari_jari = int(input("Masukkan jari-jari dari bola (cm): "))
pi = 22/7
volume_bola = 4/3 * pi * jari_jari**3
print(f"volume bola adalah {volume_bola} cm^3. ")
# Out:
# Masukkan jari-jari dari bola (cm): 7
# volume bola adalah 1437.333333333333 cm^3.

# %% [markdown]
# Aplikasi Sederhana Menghitung Volume Kerucut

# %%
tinggi_kerucut = int(input("Masukkan tinggi dari kerucut (cm): "))
jari_jari = int(input("Masukkan jari-jari dari kerucut (cm): "))
pi = 22/7
volume_kerucut = 1/3 * pi * jari_jari**2 * tinggi_kerucut
print(f"Volume kerucut adalah {volume_kerucut} cm^2. ")
# Out:
# Masukkan tinggi dari kerucut (cm): 20
# Masukkan jari-jari dari kerucut (cm): 5
# Volume kerucut adalah 523.8095238095237 cm^2.
